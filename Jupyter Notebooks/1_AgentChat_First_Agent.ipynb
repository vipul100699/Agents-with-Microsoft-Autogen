# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os

# %%
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

# %%
model_client = OpenAIChatCompletionClient(
    api_key=api_key,
    base_url="https://api.groq.com/openai/v1",
    model="llama-3.1-8b-instant",
    model_info={
        "family": "llama",
        "vision": False,
        "function_calling": True,
        "json_output": True,
    },
)
# Out:
# e:\Udemy Courses\Autogen_Crash_Course\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:466: UserWarning: Missing required field 'structured_output' in ModelInfo. This field will be required in a future version of AutoGen.
#   validate_model_info(self._model_info)

# %%
assistant = AssistantAgent(
    name='AssistantAgent',
    model_client=model_client,
    description='A Basic Assistant Agent'
)

# %%
result = await assistant.run(task="What is the capital of New Zealand?")
print(result)
# Out:
# messages=[TextMessage(id='782c9046-4117-4477-8062-d759437cbffb', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 12, 16, 8, 2, 40, 231695, tzinfo=datetime.timezone.utc), content='What is the capital of New Zealand?', type='TextMessage'), TextMessage(id='8f0577ec-5acf-4902-9c35-94e60b7609c9', source='AssistantAgent', models_usage=RequestUsage(prompt_tokens=67, completion_tokens=9), metadata={}, created_at=datetime.datetime(2025, 12, 16, 8, 2, 55, 400543, tzinfo=datetime.timezone.utc), content='The capital of New Zealand is Wellington.', type='TextMessage')] stop_reason=None

# %%
print(result.messages[-1].content)
# Out:
# The capital of New Zealand is Wellington.

# %%
result = await assistant.run(task="Provide a brief summary about the capital of Finland?")
print(result.messages[-1].content)
# Out:
# The capital of Finland is Helsinki. It is a vibrant and modern city located on the southern coast of Finland, on the shores of the Gulf of Finland. Helsinki is known for its unique blend of Finnish design, cultural attractions, and stunning natural beauty, including Suomenlinna Sea Fortress, Temppeliaukio Church, and Senate Square.
#
# Additional information on Helsinki and the surrounding area can be accessed if required.
